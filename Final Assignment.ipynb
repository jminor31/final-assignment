# %%
# %matplotlib inline
import pandas as pd
import utils

# %%
raw_data = utils.get_socrata_data("http://data.cityofchicago.org/resource/cwig-ma7x.json")
my_data = pd.DataFrame(raw_data)
# Out:
# Got http://data.cityofchicago.org/resource/cwig-ma7x.json?%24offset=0&%24limit=50000
# Writing cwig-ma7x.json?%24offset=0&%24limit=50000
# Got http://data.cityofchicago.org/resource/cwig-ma7x.json?%24offset=50000&%24limit=50000
# Writing cwig-ma7x.json?%24offset=50000&%24limit=50000
# Got http://data.cityofchicago.org/resource/cwig-ma7x.json?%24offset=100000&%24limit=50000
# Writing cwig-ma7x.json?%24offset=100000&%24limit=50000

# %%
my_data.head()
# Out:
#                address            aka_name     city  \
# 0    604 N CICERO AVE            QUICK SUB  CHICAGO
# 1      2020 W CHICAGO             BAR BARI  CHICAGO
# 2  5620 S ASHLAND AVE                  NaN  CHICAGO
# 3     2634 N CLARK ST             WINGSTOP  CHICAGO
# 4   3207 N ELSTON AVE   FOOD FIRST CHICAGO  CHICAGO
#
#                       dba_name facility_type          inspection_date  \
# 0                    QUICK SUB    Restaurant  2015-10-01T00:00:00.000
# 1                     BAR BARI    Restaurant  2011-09-12T00:00:00.000
# 2  ROYAL CATERING SERVICES,LLc    Restaurant  2013-06-28T00:00:00.000
# 3                     WINGSTOP    Restaurant  2017-01-24T00:00:00.000
# 4           FOOD FIRST CHICAGO    Restaurant  2015-12-29T00:00:00.000
#
#   inspection_id        inspection_type            latitude license_  \
# 0       1578396                Canvass   41.89154610278816  2278446
# 1        634525                Canvass  41.896004699879654  2109874
# ...

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149196 entries, 0 to 149195
# Data columns (total 17 columns):
# address            149196 non-null object
# aka_name           146524 non-null object
# city               149046 non-null object
# dba_name           149196 non-null object
# facility_type      144635 non-null object
# inspection_date    149196 non-null object
# inspection_id      149196 non-null object
# inspection_type    149195 non-null object
# latitude           148668 non-null object
# license_           149182 non-null object
# location           148668 non-null object
# longitude          148668 non-null object
# results            149196 non-null object
# risk               149130 non-null object
# state              149188 non-null object
# violations         119214 non-null object
# zip                149097 non-null object
# dtypes: object(17)
# memory usage: 19.4+ MB

# %%
my_data.facility_type.value_counts().reset_index()
# Out:
#                                                index  facility_type
# 0                                         Restaurant          97882
# 1                                      Grocery Store          20053
# 2                                             School           9394
# 3                              Daycare (2 - 6 Years)           2351
# 4                                             Bakery           2189
# 5                    Daycare Above and Under 2 Years           1662
# 6                       Children's Services Facility           1567
# 7                                     Long Term Care            883
# 8                                           Catering            858
# 9                              Mobile Food Dispenser            762
# 10                                Daycare Combo 1586            761
# 11                                            Liquor            704
# 12                                         Wholesale            512
# ...

# %%
my_data.inspection_id.sum()
# Out:
# u'...'

# %%
my_data.results.describe()
# Out:
# count     149196
# unique         7
# top         Pass
# freq       87872
# Name: results, dtype: object

# %%
my_data.results.value_counts().reset_index()
# Out:
#                   index  results
# 0                  Pass    87872
# 1                  Fail    28920
# 2    Pass w/ Conditions    14056
# 3       Out of Business    13521
# 4              No Entry     4025
# 5             Not Ready      742
# 6  Business Not Located       60
